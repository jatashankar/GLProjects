# %% [markdown]
# # Import Liberary

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Train and Test Data
train_data= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/GreatLearning/Hackathon_24Feb2024/Train_dataset_(2).csv")
test_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/GreatLearning/Hackathon_24Feb2024/Test_dataset_(2).csv")

# %%
train_data
# Out:
#       Registration Number  Annual Turnover           Cuisine        City  \
# 0                   60001         42000000      indian,irish   Bangalore
# 1                   60002         50000000      indian,irish      Indore
# 2                   60003         32500000   tibetan,italian     Chennai
# 3                   60004        110000000  turkish,nigerian     Gurgaon
# 4                   60005         20000000     irish,belgian     Manesar
# ...                   ...              ...               ...         ...
# 3488                63489         40500000  algerian,belgian          -1
# 3489                63490         32500000     tibetan,greek  Bangalore
# 3490                63491         42500000      indian,irish     Chennai
# 3491                63492         53000000     japanese,thai   Bangalore
# 3492                63493         12000000      indian,irish   Ghaziabad
#
#      Restaurant Location Opening Day of Restaurant  \
# ...

# %%
test_data.shape
# Out:
# (500, 33)

# %%
train_data.shape
# Out:
# (3493, 34)

# %%
#Summary Statistics
print(train_data.info())
print(train_data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3493 entries, 0 to 3492
# Data columns (total 34 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Registration Number            3493 non-null   int64
#  1   Annual Turnover                3493 non-null   int64
#  2   Cuisine                        3493 non-null   object
#  3   City                           3493 non-null   object
#  4   Restaurant Location            3493 non-null   object
#  5   Opening Day of Restaurant      3493 non-null   object
#  6   Facebook Popularity Quotient   3394 non-null   float64
#  7   Endorsed By                    3493 non-null   object
#  8   Instagram Popularity Quotient  3437 non-null   float64
#  9   Fire Audit                     3493 non-null   int64
#  10  Liquor License Obtained        3493 non-null   int64
#  11  Situated in a Multi Complex    3493 non-null   int64
# ...

# %%
# Identify missing values
missing_values = train_data.isnull().sum()
# Display columns with missing values
print("Columns with Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with Missing Values:
# Facebook Popularity Quotient       99
# Instagram Popularity Quotient      56
# Resturant Tier                     49
# Overall Restaurant Rating         212
# Live Music Rating                 765
# Comedy Gigs Rating               2483
# Value Deals Rating               2707
# Live Sports Rating               3288
# Ambience                           25
# dtype: int64

# %%
# Identify missing values
missing_values_test = test_data.isnull().sum()
# Display columns with missing values
print("Columns with Missing Values:")
print(missing_values_test[missing_values_test > 0])
# Out:
# Columns with Missing Values:
# Overall Restaurant Rating     34
# Live Music Rating            102
# Comedy Gigs Rating           370
# Value Deals Rating           385
# Live Sports Rating           471
# dtype: int64

# %%
# Fill missing values for Facebook and Instagram Popularity Quotient with mean
train_data['Facebook Popularity Quotient'].fillna(train_data['Facebook Popularity Quotient'].mean(), inplace=True)
train_data['Instagram Popularity Quotient'].fillna(train_data['Instagram Popularity Quotient'].mean(), inplace=True)

# %%
# Fill missing values for Facebook and Instagram Popularity Quotient with mean
test_data['Facebook Popularity Quotient'].fillna(test_data['Facebook Popularity Quotient'].mean(), inplace=True)
test_data['Instagram Popularity Quotient'].fillna(test_data['Instagram Popularity Quotient'].mean(), inplace=True)

# %%
# Fill missing values for Resturant Tier and Ambience with mode
train_data['Resturant Tier'].fillna(train_data['Resturant Tier'].mode()[0], inplace=True)
train_data['Ambience'].fillna(train_data['Ambience'].mode()[0], inplace=True)

# %%
# Fill missing values for Resturant Tier and Ambience with mode
test_data['Resturant Tier'].fillna(test_data['Resturant Tier'].mode()[0], inplace=True)
test_data['Ambience'].fillna(test_data['Ambience'].mode()[0], inplace=True)

# %%
# Fill missing values for Overall Restaurant Rating and Live Music Rating with mean
train_data['Overall Restaurant Rating'].fillna(train_data['Overall Restaurant Rating'].mean(), inplace=True)
train_data['Live Music Rating'].fillna(train_data['Live Music Rating'].mean(), inplace=True)

# %%
# Fill missing values for Overall Restaurant Rating and Live Music Rating with mean
test_data['Overall Restaurant Rating'].fillna(test_data['Overall Restaurant Rating'].mean(), inplace=True)
test_data['Live Music Rating'].fillna(test_data['Live Music Rating'].mean(), inplace=True)

# %%
# Drop columns with a large number of missing values
train_data.drop(['Comedy Gigs Rating', 'Value Deals Rating', 'Live Sports Rating'], axis=1, inplace=True)

# %%
# Drop columns with a large number of missing values
test_data.drop(['Comedy Gigs Rating', 'Value Deals Rating', 'Live Sports Rating'], axis=1, inplace=True)

# %%
# Drop remaining rows with missing values
train_data.dropna(inplace=True)

# %%
# Drop remaining rows with missing values
test_data.dropna(inplace=True)

# %%
#city has -1 value.. Lets imput with mode
train_data['City'].replace('-1', 'Unknown', inplace=True)

# %%
#city has -1 value.. Lets imput with mode
test_data['City'].replace('-1', 'Unknown', inplace=True)

# %%
train_data
# Out:
#       Registration Number  Annual Turnover           Cuisine        City  \
# 0                   60001         42000000      indian,irish   Bangalore
# 1                   60002         50000000      indian,irish      Indore
# 2                   60003         32500000   tibetan,italian     Chennai
# 3                   60004        110000000  turkish,nigerian     Gurgaon
# 4                   60005         20000000     irish,belgian     Manesar
# ...                   ...              ...               ...         ...
# 3488                63489         40500000  algerian,belgian     Unknown
# 3489                63490         32500000     tibetan,greek  Bangalore
# 3490                63491         42500000      indian,irish     Chennai
# 3491                63492         53000000     japanese,thai   Bangalore
# 3492                63493         12000000      indian,irish   Ghaziabad
#
#      Restaurant Location Opening Day of Restaurant  \
# ...

# %%
train_data['City'].value_counts()
# Out:
# Bangalore      553
# Unknown        396
# Noida          324
# Hyderabad      295
# Pune           262
#               ...
# Miryalaguda      1
#  mumbai          1
# Dharuhera        1
# meerut           1
# pondy            1
# Name: City, Length: 297, dtype: int64

# %%
# Remove space
def lower_case(x):
    x=x.strip()
    return x.lower()

# %%
train_data['City']=train_data['City'].apply(lambda x: lower_case(x))

# %%
test_data['City']=test_data['City'].apply(lambda x: lower_case(x))

# %%
train_data['City'].value_counts()
# Out:
# bangalore                 585
# unknown                   396
# noida                     345
# hyderabad                 325
# pune                      295
#                          ...
# indirapuram, ghaziabad      1
# gagret                      1
# bellary                     1
# calicut                     1
# pondy                       1
# Name: City, Length: 203, dtype: int64

# %%
#Again Check Missing Value

missing_values = train_data.isnull().sum()
# Display columns with missing values
print("Columns with Missing Values:")
print(missing_values[missing_values > 0])
# Out:
# Columns with Missing Values:
# Series([], dtype: int64)

# %%
train_data.isnull().sum()
# Out:
# Registration Number              0
# Annual Turnover                  0
# Cuisine                          0
# City                             0
# Restaurant Location              0
# Opening Day of Restaurant        0
# Facebook Popularity Quotient     0
# Endorsed By                      0
# Instagram Popularity Quotient    0
# Fire Audit                       0
# Liquor License Obtained          0
# Situated in a Multi Complex      0
# Dedicated Parking                0
# Open Sitting Available           0
# Resturant Tier                   0
# Restaurant Type                  0
# Restaurant Theme                 0
# Restaurant Zomato Rating         0
# Restaurant City Tier             0
# Order Wait Time                  0
# Staff Responsivness              0
# Value for Money                  0
# Hygiene Rating                   0
# Food Rating                      0
# Overall Restaurant Rating        0
# Live Music Rating                0
# Ambience                         0
# ...

# %%
test_data.isnull().sum()
# Out:
# Registration Number              0
# Cuisine                          0
# City                             0
# Restaurant Location              0
# Opening Day of Restaurant        0
# Facebook Popularity Quotient     0
# Endoresed By                     0
# Instagram Popularity Quotient    0
# Fire Audit                       0
# Liquor License Obtained          0
# Situated in a Multi Complex      0
# Dedicated Parking                0
# Open Sitting Available           0
# Resturant Tier                   0
# Restaurant Type                  0
# Restaurant Theme                 0
# Restaurant Zomato Rating         0
# Restaurant City Tier             0
# Order Wait Time                  0
# Staff Responsivness              0
# Value for Money                  0
# Hygiene Rating                   0
# Food Rating                      0
# Overall Restaurant Rating        0
# Live Music Rating                0
# Ambience                         0
# Lively                           0
# ...

# %%
from datetime import date

# %%
# Opening Day of Restaurant

current=date.today()
current.year

train_data['Opening_days'] = (pd.to_datetime(current) - pd.to_datetime(train_data['Opening Day of Restaurant'])).dt.days

test_data['Opening_days'] = (pd.to_datetime(current) - pd.to_datetime(test_data['Opening Day of Restaurant'])).dt.days

# %%
train_data
# Out:
#       Registration Number  Annual Turnover           Cuisine       City  \
# 0                   60001         42000000      indian,irish  bangalore
# 1                   60002         50000000      indian,irish     indore
# 2                   60003         32500000   tibetan,italian    chennai
# 3                   60004        110000000  turkish,nigerian    gurgaon
# 4                   60005         20000000     irish,belgian    manesar
# ...                   ...              ...               ...        ...
# 3488                63489         40500000  algerian,belgian    unknown
# 3489                63490         32500000     tibetan,greek  bangalore
# 3490                63491         42500000      indian,irish    chennai
# 3491                63492         53000000     japanese,thai  bangalore
# 3492                63493         12000000      indian,irish  ghaziabad
#
#      Restaurant Location Opening Day of Restaurant  \
# ...

# %%
train_data.shape
# Out:
# (3493, 32)

# %%
test_data.shape
# Out:
# (500, 31)

# %%
# Encoding
train_data_encode = train_data.copy()
test_data_encode = test_data.copy()

# %%
cuisine=train_data_encode['Cuisine'].value_counts().index
for cat_var in cuisine:
    train_data_encode['Cuisine_'+cat_var]=np.where(train_data_encode['Cuisine']==cat_var, 1,0)
train_data_encode.shape
# Out:
# (3493, 52)

# %%
cuisine=test_data_encode['Cuisine'].value_counts().index
for cat_var in cuisine:
    test_data_encode['Cuisine_'+cat_var]=np.where(test_data_encode['Cuisine']==cat_var, 1,0)
test_data_encode.shape
# Out:
# (500, 51)

# %%
city=train_data_encode['City'].value_counts().index
for cat_var in city:
    train_data_encode['City_'+cat_var]=np.where(train_data_encode['City']==cat_var, 1,0)
train_data_encode.shape
# Out:
# <ipython-input-885-4e092048f6cd>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['City_'+cat_var]=np.where(train_data_encode['City']==cat_var, 1,0)
# <ipython-input-885-4e092048f6cd>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['City_'+cat_var]=np.where(train_data_encode['City']==cat_var, 1,0)
# ...

# %%
city=test_data_encode['City'].value_counts().index
for cat_var in city:
    test_data_encode['City_'+cat_var]=np.where(test_data_encode['City']==cat_var, 1,0)
test_data_encode.shape
# Out:
# (500, 125)

# %%
location=train_data_encode['Restaurant Location'].value_counts().index
for cat_var in location:
    train_data_encode['Restaurant Location_'+cat_var]=np.where(train_data_encode['Restaurant Location']==cat_var, 1,0)
train_data_encode.shape
# Out:
# <ipython-input-887-22c29db4022c>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Location_'+cat_var]=np.where(train_data_encode['Restaurant Location']==cat_var, 1,0)
# <ipython-input-887-22c29db4022c>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Location_'+cat_var]=np.where(train_data_encode['Restaurant Location']==cat_var, 1,0)
# (3493, 257)

# %%
location=test_data_encode['Restaurant Location'].value_counts().index
for cat_var in location:
    test_data_encode['Restaurant Location_'+cat_var]=np.where(test_data_encode['Restaurant Location']==cat_var, 1,0)
test_data_encode.shape
# Out:
# (500, 127)

# %%
endorsed=train_data_encode['Endorsed By'].value_counts().index
for cat_var in endorsed:
    train_data_encode['Endorsed By_'+cat_var]=np.where(train_data_encode['Endorsed By']==cat_var, 1,0)
train_data_encode.shape
# Out:
# <ipython-input-889-b334559fcd9f>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Endorsed By_'+cat_var]=np.where(train_data_encode['Endorsed By']==cat_var, 1,0)
# <ipython-input-889-b334559fcd9f>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Endorsed By_'+cat_var]=np.where(train_data_encode['Endorsed By']==cat_var, 1,0)
# ...

# %%
test_data_encode.rename(columns={'Endoresed By': 'Endorsed By'}, inplace=True)

# %%
endorsed1=test_data_encode['Endorsed By'].value_counts().index
for cat_var in endorsed1:
    test_data_encode['Endorsed By_'+cat_var]=np.where(test_data_encode['Endorsed By']==cat_var, 1,0)
test_data_encode.shape
# Out:
# <ipython-input-891-c474c764ea07>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Endorsed By_'+cat_var]=np.where(test_data_encode['Endorsed By']==cat_var, 1,0)
# <ipython-input-891-c474c764ea07>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Endorsed By_'+cat_var]=np.where(test_data_encode['Endorsed By']==cat_var, 1,0)
# (500, 130)

# %%
rtype=train_data_encode['Restaurant Type'].value_counts().index
for cat_var in rtype:
    train_data_encode['Restaurant Type_'+cat_var]=np.where(train_data_encode['Restaurant Type']==cat_var, 1,0)
train_data_encode.shape
# Out:
# <ipython-input-892-87062c436770>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Type_'+cat_var]=np.where(train_data_encode['Restaurant Type']==cat_var, 1,0)
# <ipython-input-892-87062c436770>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Type_'+cat_var]=np.where(train_data_encode['Restaurant Type']==cat_var, 1,0)
# ...

# %%
rtype=test_data_encode['Restaurant Type'].value_counts().index
for cat_var in rtype:
    test_data_encode['Restaurant Type_'+cat_var]=np.where(test_data_encode['Restaurant Type']==cat_var, 1,0)
test_data_encode.shape
# Out:
# <ipython-input-893-d70ca56c10f1>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Restaurant Type_'+cat_var]=np.where(test_data_encode['Restaurant Type']==cat_var, 1,0)
# <ipython-input-893-d70ca56c10f1>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Restaurant Type_'+cat_var]=np.where(test_data_encode['Restaurant Type']==cat_var, 1,0)
# ...

# %%
theme=train_data_encode['Restaurant Theme'].value_counts().index
for cat_var in theme:
    train_data_encode['Restaurant Theme_'+cat_var]=np.where(train_data_encode['Restaurant Theme']==cat_var, 1,0)
train_data_encode.shape
# Out:
# <ipython-input-894-97e65e2ec380>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Theme_'+cat_var]=np.where(train_data_encode['Restaurant Theme']==cat_var, 1,0)
# <ipython-input-894-97e65e2ec380>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   train_data_encode['Restaurant Theme_'+cat_var]=np.where(train_data_encode['Restaurant Theme']==cat_var, 1,0)
# ...

# %%
theme=test_data_encode['Restaurant Theme'].value_counts().index
for cat_var in theme:
    test_data_encode['Restaurant Theme_'+cat_var]=np.where(test_data_encode['Restaurant Theme']==cat_var, 1,0)
test_data_encode.shape
# Out:
# <ipython-input-895-c7a227cc1279>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Restaurant Theme_'+cat_var]=np.where(test_data_encode['Restaurant Theme']==cat_var, 1,0)
# <ipython-input-895-c7a227cc1279>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_data_encode['Restaurant Theme_'+cat_var]=np.where(test_data_encode['Restaurant Theme']==cat_var, 1,0)
# ...

# %%
train_data_encode.drop(columns=['Cuisine', 'City', 'Restaurant Location', 'Endorsed By','Restaurant Type', 'Restaurant Theme'],inplace=True)
train_data_encode.shape
# Out:
# (3493, 292)

# %%
test_data_encode.drop(columns=['Cuisine', 'City', 'Restaurant Location', 'Endorsed By','Restaurant Type', 'Restaurant Theme'],inplace=True)
test_data_encode.shape
# Out:
# (500, 146)

# %%
train_data_encode.drop(columns=['Registration Number'],inplace=True)
test_data_encode.drop(columns=['Registration Number'],inplace=True)

# %%
train_data_encode.drop(columns=['Opening Day of Restaurant'],inplace=True)
test_data_encode.drop(columns=['Opening Day of Restaurant'],inplace=True)

# %%
train_data_encode.drop(columns=['Fire Audit'],inplace=True)
test_data_encode.drop(columns=['Fire Audit'],inplace=True)

# %%
train_data_encode.drop(columns=['Situated in a Multi Complex'],inplace=True)
test_data_encode.drop(columns=['Situated in a Multi Complex'],inplace=True)

# %%
train_data_encode.reset_index(drop=True,inplace=True)
test_data_encode.reset_index(drop=True,inplace=True)

# %%
train_data_df = train_data_encode.copy()
test_data_df = test_data_encode.copy()

# %%
train_data_df.columns = train_data_df.columns.str.replace(',', '_').str.replace('/', '_').str.replace('(', '_').str.replace('-', '_').str.replace('&', '_').str.replace(' ', '').str.replace(')', '')
test_data_df.columns = test_data_df.columns.str.replace(',', '_').str.replace('/', '_').str.replace('(', '_').str.replace('-', '_').str.replace('&', '_').str.replace(' ', '').str.replace(')', '')
# Out:
# <ipython-input-904-c5b830250b23>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   train_data_df.columns = train_data_df.columns.str.replace(',', '_').str.replace('/', '_').str.replace('(', '_').str.replace('-', '_').str.replace('&', '_').str.replace(' ', '').str.replace(')', '')
# <ipython-input-904-c5b830250b23>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   train_data_df.columns = train_data_df.columns.str.replace(',', '_').str.replace('/', '_').str.replace('(', '_').str.replace('-', '_').str.replace('&', '_').str.replace(' ', '').str.replace(')', '')
# ...

# %%
result_df = pd.DataFrame(columns=['Modal Name', 'Cross-validated RMSE', 'Holdout set RMSE'])

# Displaying the DataFrame
print(result_df)
# Out:
# Empty DataFrame
# Columns: [Modal Name, Cross-validated RMSE, Holdout set RMSE]
# Index: []

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = train_data_df.drop('AnnualTurnover', axis=1)
y = train_data_df['AnnualTurnover']

# %%
# Align columns in training and test datasets
X, test_data_df = X.align(test_data_df, join='left', axis=1, fill_value=0)

# %%
# Step 3: Feature Scaling
scaler = StandardScaler()
features_scaled = scaler.fit_transform(X)

# %%
# Choose Linear Regression and train it
ln_model = LinearRegression()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(ln_model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 2.7437875617710657e+21

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
ln_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = ln_model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 1.0736866762640057e+23
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Sample data for a new row
new_data = {'Modal Name': 'LinearRegression', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
# Out:
# <ipython-input-914-1fb86a6b51dd>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)

# %%
# Step 4: Model Selection
# Choose RandomForestRegressor and train it
model = RandomForestRegressor()

# %%
# Step 5: Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 20496491.668177877

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 43673728.945033245
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
# Sample data for a new row
new_data = {'Modal Name': 'RandomForestRegressor', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
# Out:
# <ipython-input-919-f2faadfb9252>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)

# %%
result_df
# Out:
#               Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0       LinearRegression          2.743788e+21      1.073687e+23
# 1  RandomForestRegressor          2.049649e+07      4.367373e+07

# %%
from sklearn.svm import SVR

# %%
# Model Selection - SVR
model = SVR()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 21512994.45673562

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# SVR()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Holdout set RMSE: 21336602.55255599

# %%
new_data = {'Modal Name': 'SVR', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
# Out:
# <ipython-input-926-6002797f9631>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)

# %%
result_df
# Out:
#               Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0       LinearRegression          2.743788e+21      1.073687e+23
# 1  RandomForestRegressor          2.049649e+07      4.367373e+07
# 2                    SVR          2.151299e+07      2.133660e+07

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Model Selection - GradientBoostingRegressor
model = GradientBoostingRegressor()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 20436734.190377284

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 43737554.127284035
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data = {'Modal Name': 'GradientBoostingRegressor', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
# Out:
# <ipython-input-933-5a5f9a7726d4>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)

# %%
result_df
# Out:
#                   Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0           LinearRegression          2.743788e+21      1.073687e+23
# 1      RandomForestRegressor          2.049649e+07      4.367373e+07
# 2                        SVR          2.151299e+07      2.133660e+07
# 3  GradientBoostingRegressor          2.043673e+07      4.373755e+07

# %%
from xgboost import XGBRegressor

# %%
# Model Selection - XGBoost
model = XGBRegressor()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 21372690.876812078

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 59073722.82255645
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data = {'Modal Name': 'XGBRegressor', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
result_df
# Out:
# <ipython-input-940-07a5c7e2641f>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)
#                   Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0           LinearRegression          2.743788e+21      1.073687e+23
# 1      RandomForestRegressor          2.049649e+07      4.367373e+07
# 2                        SVR          2.151299e+07      2.133660e+07
# 3  GradientBoostingRegressor          2.043673e+07      4.373755e+07
# 4               XGBRegressor          2.137269e+07      5.907372e+07

# %%
from sklearn.linear_model import LassoCV

# %%
# Model Selection - LassoCV
model = LassoCV()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 19974729.370004404

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# LassoCV()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 121561664.51210827
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data = {'Modal Name': 'LassoCV', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
result_df
# Out:
# <ipython-input-946-45bc1b18c432>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)
#                   Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0           LinearRegression          2.743788e+21      1.073687e+23
# 1      RandomForestRegressor          2.049649e+07      4.367373e+07
# 2                        SVR          2.151299e+07      2.133660e+07
# 3  GradientBoostingRegressor          2.043673e+07      4.373755e+07
# 4               XGBRegressor          2.137269e+07      5.907372e+07
# 5                    LassoCV          1.997473e+07      1.215617e+08

# %%
from sklearn.linear_model import ElasticNetCV

# %%
# Model Selection - ElasticNetCV
model = ElasticNetCV()

# %%
# Model Validation using k-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_rmse = np.sqrt(-cross_val_score(model, features_scaled, y, scoring="neg_mean_squared_error", cv=kf))
print(f'Cross-validated RMSE: {cv_rmse.mean()}')
# Out:
# Cross-validated RMSE: 21508910.914441973

# %%
# Train the model on the entire training set
X_train, X_test, y_train, y_test = train_test_split(features_scaled, y, test_size=0.2, random_state=42)
model.fit(X_train, y_train)
# Out:
# ElasticNetCV()

# %%
# Model Evaluation on the holdout set
X_test_scaled = scaler.transform(X_test)
predictions = model.predict(X_test_scaled)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f'Holdout set RMSE: {rmse}')
# Out:
# Holdout set RMSE: 21317125.75712212
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data = {'Modal Name': 'ElasticNetCV', 'Cross-validated RMSE': cv_rmse.mean(), 'Holdout set RMSE': rmse}

# Append the new row to the DataFrame
result_df = result_df.append(new_data, ignore_index=True)
result_df
# Out:
# <ipython-input-952-8ad190eec75e>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(new_data, ignore_index=True)
#                   Modal Name  Cross-validated RMSE  Holdout set RMSE
# 0           LinearRegression          2.743788e+21      1.073687e+23
# 1      RandomForestRegressor          2.049649e+07      4.367373e+07
# 2                        SVR          2.151299e+07      2.133660e+07
# 3  GradientBoostingRegressor          2.043673e+07      4.373755e+07
# 4               XGBRegressor          2.137269e+07      5.907372e+07
# 5                    LassoCV          1.997473e+07      1.215617e+08
# 6               ElasticNetCV          2.150891e+07      2.131713e+07

# %%
# Submission File
# Make predictions on the test set and create the submission file
test_data_scaled = scaler.transform(test_data_df)
test_predictions = model.predict(test_data_scaled)

# %%
submission = pd.DataFrame({'Registration Number': test_data['Registration Number'], 'Annual Turnover': test_predictions})
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/GreatLearning/Hackathon_24Feb2024/submission.csv', index=False)
